# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathamesh-Brahma/ML/blob/main/IR9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

seed_url = "https://www.formula1.com/"
max_depth = 1
visited = set()
queue = [(seed_url, 0)]

print("Crawling started...")

while queue:
    url, depth = queue.pop(0)
    if url in visited or depth > max_depth:
        continue

    visited.add(url)
    print(f"Depth {depth}: {url}")

    try:
        soup = BeautifulSoup(requests.get(url, timeout=5).content, "html.parser")

        for tag in soup.find_all("a", href=True):
            link = urljoin(url, tag['href'])
            if link not in visited:
                queue.append((link, depth + 1))
    except Exception:
        pass

print(f"Done. Total pages visited: {len(visited)}")
# Out:
# Crawling started...
# Depth 0: https://www.formula1.com/
# Depth 1: https://www.formula1.com/#maincontent
# Depth 1: https://www.f1authentics.com/?utm_source=f1&utm_medium=website_topnav&utm_campaign=2026_season
# Depth 1: https://f1store.formula1.com/en/?_s=bm-fi-f1-prtsite-topnav-230720-jm
# Depth 1: https://tickets.formula1.com
# Depth 1: https://tickets.formula1.com/en/h-formula1-hospitality
# Depth 1: https://f1experiences.com/?utm_source=formula1.com&utm_medium=referral&utm_campaign=general
# Depth 1: https://f1tv.formula1.com
# Depth 1: https://account.formula1.com/#/en/login?redirect=https%3A%2F%2Fwww.formula1.com%2Fen&lead_source=web_f1core
# Depth 1: https://www.formula1.com/subscribe-to-f1-tv
# Depth 1: https://www.formula1.com/en/racing/2026
# Depth 1: https://www.formula1.com/en/racing/2026/china
# Depth 1: https://www.formula1.com/en/racing/2026/japan
# Depth 1: https://www.formula1.com/en/racing/2026/miami
# Depth 1: https://www.formula1.com/en/racing/2026/canada
# ...
